# %% [markdown]
# ***If Else Elif***

# %%
age = int(input("Enter your age"))
if (age >= 18):
    print("you are eligible to vote")
else:
    print("you are not elegible")
# Out:
# Enter your age 34
# you are eligible to vote

# %%
marks = int(input("Enter you Marks"))

if (marks>=80):
    print("You got Grade A")
elif(marks>=70):
    print("You got Grade B")
elif(marks>=60):
    print("You got Grade C")
elif(marks>=50):
    print("You got Grade D")
else:
    print("You got You Failed")
# Out:
# Enter you Marks 78
# You got Grade B

# %% [markdown]
# ***Questions?***

# %%
number = int(input("enter a number"))
if (number>100):print("it's greater than 100")
# Out:
# enter a number 890
# it's greater than 100

# %%
password = input("enter a password")
if (len(password)>8):
    print ("Strong password")
# Out:
# enter a password 75876689968
# Strong password

# %%
marks = int(input("Enter your Marks"))
if (marks>=95): print("Excellent")
# Out:
# Enter your Marks 98
# Excellent

# %%
temp = int(input("what's the temperature"))
if (temp>40):
    print("Very Hot")
# Out:
# what's the temperature 50
# Very Hot

# %%
number = int(input("write a number"))
if (number%10 == 0): print("Multiple of 10")
# Out:
# write a number 56

# %%
number = int(input("enter a number"))
if (number == 49): print("Perfect Square")
# Out:
# enter a number 49
# Perfect Square

# %%
number = int(input("enter a number"))
if (number%7==0): print("Number is divisible by 7")
else:
    print("Number is not divisible by 7")
# Out:
# enter a number 49
# Number is divisible by 7

# %%
height = int(input("Enter the height"))
if (height >150): print("you are taller than 5 ft")
else: print("you are not taller than 5 ft")
# Out:
# Enter the height 167
# you are taller than 5 ft

# %%
number = int(input("enter a number:"))
if (number>50): print("entered number is greater than 50")
else: print("entered number is less than 50")
# Out:
# enter a number: 78
# entered number is greater than 50

# %%
td = 365
att = int(input("enter the days you attended"))
attendence = (att/td)*100
if (attendence>=75):
    print("you have more attendence than 75%")
else: 
    print("you dont' have 75% attendence")
# Out:
# enter the days you attended 309
# you have more attendence than 75%

# %%
chara = input("enter a charachter")
if (type(chara) == int):
    print("it is a digit")
else :
    print("it's not a digit")
# Out:
# enter a charachter 78
# <class 'str'>

# %%
number = int(input("enter a number"))
if (number%4==0): print("Number is multiple of 4")
else:
    print("Number is not a multiple of 4")
# Out:
# enter a number 64
# Number is multiple of 4

# %%
correct_username = "Sudhanshu"
entered_username = input("Enter your username: ")

if entered_username == correct_username:
    print("Access granted. Welcome!")
else:
    print("Access denied. Incorrect username.")
# Out:
# Enter your username:  sudhanshu
# Access denied. Incorrect username.

# %%
n = int(input("enter a number"))
if (n<0): print("the number is a negative number")
else : print("it is a positive number")
# Out:
# enter a number -9
# the number is a negative number

# %%
vowel = input("Enter a letter: ")
if vowel.lower() in "aeiou":
    print("It is a vowel")
else:
    print("It is not a vowel")

# %%
number = int(input("enter a number"))
if (number % 10 == 0):
    print ("number is divisible by 2 and 5")
else:
    print("it's not divisible by 2 and 5")
# Out:
# enter a number 60
# number is divisible by 2 and 5

# %%
number = int (input("enter a number"))
if(number > 0):
    print ("it's a positive number")
elif(number == 0):
    print("it's equla to 0")
else:
    print("it's a negative number")
# Out:
# enter a number -98
# it's a negative number

# %%
marks = int(input("enter marks"))
if (marks>=90):
    print("outstanding")
elif(marks>=75 and marks<=89):
    print("very good")
elif(marks>=50 and marks<=74):
    print("good")
else:
    print("needs improement")
# Out:
# enter marks 88
# very good

# %%
number = int(input("Enter a number"))
if (number<10):
    print("Small")
elif(number>10 and number <99):
    print("medium")
elif(number>=100):
    print("Large")
# Out:
# Enter a number 560
# Large

# %%
marks = int(input("Enter your marks"))

if (marks>=80):
    print("Distinction")
elif(marks>=60):
    print("first division")
elif(marks>=40):
    print("pass")
else:
    print("fail")
# Out:
# Enter your marks 78
# first division

# %%
season = int(input("enter the month in number"))

if (season == 12 or season == 1 or season ==2):
    print("it's winter season")
elif(season == 3 or season == 4 or season ==5):
    print("it's summer season")
elif (season == 6 or season == 7 or season ==8):
    print("it's monsoon season")
elif (season == 9 or season == 10 or season ==11):
    print("it's autumn season")
# Out:
# enter the month in number 4
# it's summer season

# %%
salary = int(input("enter the salary"))
if (salary>100000):
    print("20% bonus")
elif(salary>50000):
    print("10% bonus")
else:
    print("5% bonus")
# Out:
# enter the salary 70000
# 10% bonus

# %%
speed = int(input("what's your internet speed"))
if (speed>100):
    print("fast")
elif (speed>=50):
    print("moderate")
elif (speed<50):
    print("slow")
# Out:
# what's your internet speed 98
# moderate
