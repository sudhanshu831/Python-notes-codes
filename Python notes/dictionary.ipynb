# %%
a = {"Name":"Sudhanshu","Course":"BCA","Age":20}
print(a.keys())
# Out:
# dict_keys(['Name', 'Course', 'Age'])

# %%
print(a.values())
# Out:
# dict_values(['Sudhanshu', 'BCA', 20])

# %%
print(a.items())
# Out:
# dict_items([('Name', 'Sudhanshu'), ('Course', 'BCA'), ('Age', 20)])

# %%
a.update({"marks":80})
print(a)
# Out:
# {'Name': 'Sudhanshu', 'Course': 'BCA', 'Age': 20, 'marks': 80}

# %%
a.pop("Course")
print(a)
# Out:
# {'Name': 'Sudhanshu', 'Age': 20, 'marks': 80}

# %%
print(a.get("Name"))
# Out:
# Sudhanshu

# %%
a.clear()
print(a)
# Out:
# {}
