# %% [markdown]
# ***Tuple***

# %%
a = (2,4,5,7,35,8,7,9)

# %%
print(a.count(7))
# Out:
# 2

# %%
print(a.index(9))
# Out:
# 7

# %%
print(len(a))
# Out:
# 8

# %%
print(min(a))
# Out:
# 2

# %%
print(max(a))
# Out:
# 35

# %% [markdown]
# ***Questions***

# %% [markdown]
# ***Indexing***

# %%
fruits= ("Apple","Banana","Mango","Orange","Grapes")
print(fruits[0])
# Out:
# Apple

# %%
print(fruits[4])
# Out:
# Grapes

# %%
print(fruits[2])
# Out:
# Mango

# %%
print(fruits[-2])
# Out:
# Orange

# %%
print(fruits[-3])
# Out:
# Mango

# %%
print(fruits[-2])
# Out:
# Orange

# %%
b = fruits[0]
print(b)
# Out:
# Apple

# %%
print(len(fruits))
# Out:
# 5

# %%
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])
print(fruits[4])
# Out:
# Apple
# Banana
# Mango
# Orange
# Grapes

# %%
print(fruits[0])
print(fruits[4])
# Out:
# Apple
# Grapes

# %% [markdown]
# ***Slicing***

# %%
print(fruits[0:3])
# Out:
# ('Apple', 'Banana', 'Mango')

# %%
print(fruits[-1:-4:-1])
# Out:
# ('Grapes', 'Orange', 'Mango')

# %%
print(fruits[1:3])
# Out:
# ('Banana', 'Mango')

# %%
print(fruits[1:5])
# Out:
# ('Banana', 'Mango', 'Orange', 'Grapes')

# %%
print(fruits[0:4])
# Out:
# ('Apple', 'Banana', 'Mango', 'Orange')

# %%
print(fruits[0:5])
# Out:
# ('Apple', 'Banana', 'Mango', 'Orange', 'Grapes')

# %%
print(fruits[4:0:-1])
# Out:
# ('Grapes', 'Orange', 'Mango', 'Banana')

# %%
print(fruits[0:5:2])
# Out:
# ('Apple', 'Mango', 'Grapes')

# %%
print(fruits[2:])
# Out:
# ('Mango', 'Orange', 'Grapes')

# %%
print(fruits[0:4])
# Out:
# ('Apple', 'Banana', 'Mango', 'Orange')

# %% [markdown]
# ***Count***

# %%
numbers = (10,20,30,20,40,20,50)
print(numbers.count(20))
# Out:
# 3

# %%
print(numbers.count(10))
# Out:
# 1

# %%
print(numbers.count(100))
# Out:
# 0

# %%
print(numbers.count(30))
# Out:
# 1

# %%
print(numbers.count(50))
# Out:
# 1

# %% [markdown]
# ***Index***

# %%
colors = ("blue","green","yellow","blue","pink")

# %%
print(colors.index("green"))
# Out:
# 1

# %%
print(colors.index("yellow"))
# Out:
# 2

# %%
print(colors.index("pink"))
# Out:
# 4

# %%
print(colors.index("blue"))
# Out:
# 0

# %% [markdown]
# ***length***

# %%
students = ("aman","priya","riya","rohit","neha","ankit")

# %%
print(len(students))
# Out:
# 6

# %%
print(len(students))
# Out:
# 6

# %%
a = len(students)
print(a)
# Out:
# 6

# %%
print(len(students[-1]))
# Out:
# 5

# %% [markdown]
# ***min & max***

# %%
marks = (75,92,65,88,79,95,81)

# %%
print(max(marks))
# Out:
# 95

# %%
print(min(marks))
# Out:
# 65

# %%
difference = max(marks) - min(marks)
print(difference)
# Out:
# 30

# %%
a = max(marks)
print(a)
# Out:
# 95

# %%
b = min(marks)
print(b)
# Out:
# 65

# %%
cities = ("Delhi","Mumbai","Kolkata","Chennai","Pune","Jaipur","Lucknow")

# %%
print(cities[0])
# Out:
# Delhi

# %%
print(cities[-1])
# Out:
# Lucknow

# %%
print(cities[3])
# Out:
# Chennai

# %%
print(cities[0:4])
# Out:
# ('Delhi', 'Mumbai', 'Kolkata', 'Chennai')

# %%
print(cities[3:7])
# Out:
# ('Chennai', 'Pune', 'Jaipur', 'Lucknow')

# %%
print(cities[::-1])
# Out:
# ('Lucknow', 'Jaipur', 'Pune', 'Chennai', 'Kolkata', 'Mumbai', 'Delhi')

# %%
print(cities[::2])
# Out:
# ('Delhi', 'Kolkata', 'Pune', 'Lucknow')

# %%
print(cities.index("Pune"))
# Out:
# 4

# %%
print(len(cities))
# Out:
# 7

# %%
print(cities[1:6])
# Out:
# ('Mumbai', 'Kolkata', 'Chennai', 'Pune', 'Jaipur')

# %%
numbers =(5,15,25,35,45,55,65,75,85)

# %%
print(numbers[0])
# Out:
# 5

# %%
print(numbers[-1])
# Out:
# 85

# %%
print(numbers[0:5])
# Out:
# (5, 15, 25, 35, 45)

# %%
print(numbers[5:9])
# Out:
# (55, 65, 75, 85)

# %%
print(numbers[::-1])
# Out:
# (85, 75, 65, 55, 45, 35, 25, 15, 5)

# %%
print(numbers[::3])
# Out:
# (5, 35, 65)

# %%
print(min(numbers))
# Out:
# 5

# %%
print(max(numbers))
# Out:
# 85

# %%
print(numbers.index(45))
# Out:
# 4

# %%
print(numbers.count(15))
# Out:
# 1

# %%
print(len(numbers))
# Out:
# 9

# %%
print(numbers[2:])
# Out:
# (25, 35, 45, 55, 65, 75, 85)

# %%
print(numbers[:6])
# Out:
# (5, 15, 25, 35, 45, 55)

# %%
print(numbers[3:6])
# Out:
# (35, 45, 55)

# %%
diff = max(numbers) - min(numbers)
print(diff)
# Out:
# 80
