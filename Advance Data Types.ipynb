# %% [markdown]
# ***APPEND***

# %%
fruits = ["Apple","Banana","Mango"]
fruits.append("Orange")

# %%
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
numbers = []
numbers.append(10)
numbers.append(20)
numbers.append(30)
numbers.append(40)

print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
list = [5, 10, 15]
list.append(20)
print(list)
# Out:
# [5, 10, 15, 20]

# %% [markdown]
# ***INSERT***

# %%
list = ["Red","Blue","Green"]
list.insert(1,"yellow")
print(list)
# Out:
# ['Red', 'yellow', 'Blue', 'Green']

# %%
list = [20,30,40]
list.insert(0,10)
print(list)
# Out:
# [10, 20, 30, 40]

# %%
a = ["A","B","D"]
a.insert(2,"C")
print(a)
# Out:
# ['A', 'B', 'C', 'D']

# %% [markdown]
# ***REMOVE***

# %%
b = ["pen","pencil","eraser","scale"]
b.remove("pencil")
print(b)
# Out:
# ['pen', 'eraser', 'scale']

# %%
c = [5,10,15,20]
c.remove(15)
print(c)
# Out:
# [5, 10, 20]

# %%
d = ["cat","dog","bird"]
d.remove("dog")
print(d)
# Out:
# ['cat', 'bird']

# %% [markdown]
# ***POP***

# %%
a = ["a","b","c","d"]
a.pop(3)
print(a)
# Out:
# ['a', 'b', 'c']

# %%
b = [1,2,3,4,5]
removed_b = b.pop()
print(removed_b)
print(b)
# Out:
# 5
# [1, 2, 3, 4]

# %% [markdown]
# ***SORT***

# %%
c = [45,12,78,23,9]
c.sort()
print(c)
# Out:
# [9, 12, 23, 45, 78]

# %%
d = ["Banana","Apple","Mango","Orange"]
d.sort()
print(d)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
list = [8,2,10,4,6]
list.sort(reverse=True)
print(list)
# Out:
# [10, 8, 6, 4, 2]

# %% [markdown]
# ***REVERSE***

# %%
a = [10,20,30,40]
a.reverse()
print(a)
# Out:
# [40, 30, 20, 10]

# %%
b = ["January","February","March"]
b.reverse()
print(b)
# Out:
# ['March', 'February', 'January']

# %% [markdown]
# ***COUNT***

# %%
list = [5,2,5,7,5,8,5]
print(list.count(5))
# Out:
# 4

# %%
a = ["apple","mango","apple","banana","apple"]
print(a.count("apple"))
# Out:
# 3

# %%
b = ["True","False","True","True","False"]
print(b.count("True"))
# Out:
# 3

# %% [markdown]
# ***INDEX***

# %%
list = ["Java","Python","C++","Js"]
print(list.index("Python"))
# Out:
# 1

# %%
a = [10,20,30,40,50]
print(a.index(30))
# Out:
# 2

# %%
b = ["red","green","blue","yellow"]
print(b.index("blue"))
# Out:
# 2

# %% [markdown]
# ***CLEAR***

# %%
list = [1,2,3,4,5]
print(list.clear())
# Out:
# None

# %%
cities = ["Prayagraj","Varanasi","Lucknow","Delhi","Mumbai"]
print(cities.clear())
# Out:
# None

# %%
list = [2,4,6,8,0]
print(list)
print(list.clear())
# Out:
# [2, 4, 6, 8, 0]
# None

# %% [markdown]
# ***EXTRA QUESTIONS***

# %%
list = [10,20,30]
list.append(40)
print(list)
list.insert(1,15)
print(list)
list.remove(30)
print(list)
print("final list =",list)
# Out:
# [10, 20, 30, 40]
# [10, 15, 20, 30, 40]
# [10, 15, 20, 40]
# final list = [10, 15, 20, 40]

# %%
list = [50,10,40,20]
list.sort()
print(list)
list.reverse()
print(list)
print("FInal list = ",list)
# Out:
# [10, 20, 40, 50]
# [50, 40, 20, 10]
# FInal list =  [50, 40, 20, 10]

# %%
list = ["A","B","A","C","A"]
print(list.count("A"))
print(list.index("C"))
# Out:
# 3
# 3

# %%
list = ["Python","Java","C++","Js"]
list.remove("Java")
print(list)
list.append("SQL")
print(list)
list.sort()
print(list)
list.reverse()
print(list)
print("Final list =",list)
# Out:
# ['Python', 'C++', 'Js']
# ['Python', 'C++', 'Js', 'SQL']
# ['C++', 'Js', 'Python', 'SQL']
# ['SQL', 'Python', 'Js', 'C++']
# Final list = ['SQL', 'Python', 'Js', 'C++']

# %%
list = [100,200,300,400,500]
list.pop()
print(list)
list.insert(2,250)
print(list)
print(list.index(400))
list.clear()
print(list)
# Out:
# [100, 200, 300, 400]
# [100, 200, 250, 300, 400]
# 4
# []
