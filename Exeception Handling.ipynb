# %%
try:
    a = int(input("enter number"))
    b = int(input("enter number"))
    c = a/b
    print (c)

except ZeroDivisionError:
    print("You have entered 0 in B")
# Out:
# enter number 1
# enter number 0
# You have entered 0 in B

# %%
try:
    a = int(input("Enter number"))
    print(a)

except ValueError:
    print("You have entered a String insted of number")
# Out:
# Enter number e
# You have entered a String insted of number

# %%
try:
    list = [1,2,3,4,5]
    index = int(input("enter index"))
    print(list[index])

except IndexError:
    print("Index out of range")
except ValueError:
    print("Enter a valid number")
# Out:
# enter index 3
# 4

# %%
try: 
    a = int(input("enter a number"))
    b = int(input("enter a number"))
    sum = a+b
    print(sum)
except ValueError:
    print("You have entered a String insted of number")
# Out:
# enter a number a
# You have entered a String insted of number

# %%
import math

try:
    num = float(input("Enter a number: "))
    if num < 0:
        raise ValueError("Cannot calculate square root of a negative number.")
    print("Square root:", math.sqrt(num))

except ValueError as e:
    print("Error:", e)
# Out:
# Enter a number:  -7
# Error: Cannot calculate square root of a negative number.

# %%
try:
    a = str(input("Enter a string"))
    b = list(a)
    print(type(b),b)

except ValueError:
    print("Error")
# Out:
# Enter a string he!0:
# <class 'list'> ['h', 'e', '!', '0', ':']

# %%
try:
    a = (3,9,57,98,2)
    index = int(input("enter index"))
    print(a[index])
    print(type(a))

except IndexError:
    print("Index out of range")
except ValueError:
    print("Enter a valid number")
# Out:
# enter index 0
# 3
# <class 'tuple'>
