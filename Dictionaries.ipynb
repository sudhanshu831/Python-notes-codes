# %% [markdown]
# ***Dictionary Question***

# %%
student = {"name":"Amit", "age":20, "course":"python", "marks":85}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course', 'marks'])

# %%
print(student.values())
# Out:
# dict_values(['Amit', 20, 'python', 85])

# %%
print(len(student))
# Out:
# 4

# %%
values_list = list(student.values())
print(values_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 values_list = list(student.values())
#       2 print(values_list)
#
# TypeError: 'dict_keys' object is not callable

# %%
print(student.items())
# Out:
# dict_items([('name', 'Amit'), ('age', 20), ('course', 'python'), ('marks', 85)])

# %%
 print(student.get("course"))
# Out:
# python

# %%
print(student.get("age"))
# Out:
# 20
